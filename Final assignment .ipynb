# %% [markdown]
# # Data cleaning

# %% [markdown]
# ### Hi! My name is Gustavo Montenegro, I hope this notebook can be enough easy to read for you.

# %% [markdown]
# In this notebook I use the most popular neighborhoods in the boroughs which I want to compare.
# The Data Frame for each borough is in a CSV file that I´ve created in diferent notebooks.
#
# You can see in my github repository how I builded the Data Frames.
# https://github.com/GustavoMontenegroVargas/Coursera_Capstone
# - The 'C' Notebook has the Data from the Cuauhtémoc borough.The Downtown is there.
# - The 'T' Notebook has the Data from the Tláhuac borough. There is my local economy.
#
# I use these Data Frames in order to get two parameters: Rating and number of similar venues. With this parameters I will make an analysis. I want to answer this question: 'How can I open a similar venue in my local economy like the most popular from the Downtown?'
#
# I know, If I want to open a venue, I need a Market study.  But with this idea someones can get a few useful information about their local economy.
#
# In this notebook I use the Foursquare API in order to get the recommended venues and the details of each one. You can see my complete code in order to extract information from a JSON file.
#
# So, I didn´t use any of Machine learning algorithm, in fact, a good idea could be a multiple linear regressión with the historical data for each cluster of venues. We could predict the business performance.
#
# How I didn't have enough time to search Data Frames with that kind of information, then the parameters are the most common but they are very useful.
#
# Note: When I´m saying 'The most popular neighborhoods in each borough' I want to say the neighborhoods that I've visited because they are very popular.

# %% [markdown]
# ### The notebook starts here.

# %% [markdown]
# I need to import some libraries.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %% [markdown]
# With this code I can open the CSv that I have in the IBM cloud storage. This is the Data Frame of the Cuahtémoc borough.

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage.    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_30e6154c81ce458e9a81cf92d1db1713.get_object(Bucket='courseracapstone-donotdelete-pr-tjqo81z1sickby',Key='C.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

C = pd.read_csv(body)
C.head()
# Out:
#           Neighborhood  Postal Code   Latitude  Longitude
# 0              Algarin         6880  19.405455 -99.140086
# 1  Ampliación Asturias         6890  19.407207 -99.131016
# 2             Asturias         6850  19.404581 -99.130911
# 3              Atlampa         6450  19.456785 -99.156875
# 4           Buenavista         6350  19.446167 -99.152696

# %% [markdown]
# This is the Data Frame of the Tláhuac borough.

# %%
body = client_30e6154c81ce458e9a81cf92d1db1713.get_object(Bucket='courseracapstone-donotdelete-pr-tjqo81z1sickby',Key='T.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

T = pd.read_csv(body)
T.head()
# Out:
#                      Neighborhood  Postal Code   Latitude  Longitude
# 0          Agrícola Metropolitana        13280  19.290832 -99.052493
# 1  Ampliación José López Portillo        13419  19.313111 -99.027129
# 2          Ampliación La Conchita        13545  19.335036 -98.977113
# 3           Ampliación Los Olivos        13219  19.320556 -99.151701
# 4       Ampliación Santa Catarina        13120  19.318017 -98.963729

# %% [markdown]
# I need to get the most popular neigborhoods in a Data Frame from the Cuahtémoc borough. I wil call it 'CN'.

# %%
CN = C[4:5].append(C[6:14]).append(C[15:16]).append(C[22:24]).append(C[31:33]).append(C[36:37])
CN.reset_index(inplace = True)
CN.drop('index',axis=1,inplace=True)
CN
# Out:
#              Neighborhood  Postal Code   Latitude  Longitude
# 0              Buenavista         6350  19.446167 -99.152696
# 1         Centro (Área 1)         6000  19.432700 -99.137600
# 2         Centro (Área 2)         6010  19.439600 -99.136600
# 3         Centro (Área 3)         6020  19.438400 -99.128500
# 4         Centro (Área 4)         6040  19.430900 -99.149900
# 5         Centro (Área 5)         6050  19.433700 -99.144300
# 6         Centro (Área 6)         6060  19.431700 -99.129500
# 7         Centro (Área 7)         6070  19.428900 -99.145200
# 8         Centro (Área 8)         6080  19.426000 -99.138800
# 9                 Condesa         6140  19.414864 -99.176429
# 10              Hipódromo         6100  19.409371 -99.171213
# 11      Hipódromo Condesa         6170  19.409266 -99.179582
# 12             Roma Norte         6700  19.418323 -99.162565
# 13               Roma Sur         6760  19.405833 -99.163304
# 14  Santa María la Ribera         6400  19.448417 -99.157975

# %% [markdown]
# In order to use the Foursquare API I need to define the credetials of my Coursera Capstone App.

# %%
CLIENT_ID = 'A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU' # your Foursquare ID
CLIENT_SECRET = 'S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU
# CLIENT_SECRET:S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV

# %% [markdown]
# When I make a call to Foursquere API I need this kind of code. Each call give me a JSON file. The JSON file is a dictonarie, so I can get the information with the keys.
# In this 'for loop' I will get the relevant data of each ten venues each neighborhood from the JSON files. How the 'endpoint' is 'explore', then Foursquere will give me the ten most popular venues by rating for each neighborhood.

# %%
radius = 500 # This the raduis from the center of the neighborhood.
LIMIT = 10  # This is the number of venues that I want to get. 
ID = []
Name = []
#Rating = []

for j in range(len(CN)):
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, CN['Latitude'][j],CN['Longitude'][j], VERSION, radius, LIMIT)
    print(CN['Neighborhood'][j], url , j)
    results = requests.get(url).json()
    for i in range(10):
        ID.append(results['response']['groups'][0]['items'][i]['venue']['id'])# I can extract the venue ID and put it in a list.
        Name.append(results['response']['groups'][0]['items'][i]['venue']['name'])# I can extract the Venue name and put it in a list.
        
print(len(ID))
len((Name))
# Out:
# Buenavista https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.446167000000003,-99.15269609999999&v=20180605&radius=500&limit=10 0
# Centro (Área 1) https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4327,-99.1376&v=20180605&radius=500&limit=10 1
# Centro (Área 2) https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4396,-99.1366&v=20180605&radius=500&limit=10 2
# Centro (Área 3) https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4384,-99.1285&v=20180605&radius=500&limit=10 3
# Centro (Área 4) https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4309,-99.1499&v=20180605&radius=500&limit=10 4
# Centro (Área 5) https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4337,-99.1443&v=20180605&radius=500&limit=10 5
# Centro (Área 6) https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4317,-99.1295&v=20180605&radius=500&limit=10 6
# Centro (Área 7) https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4289,-99.1452&v=20180605&radius=500&limit=10 7
# Centro (Área 8) https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.426,-99.1388&v=20180605&radius=500&limit=10 8
# Condesa https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4148639,-99.176429&v=20180605&radius=500&limit=10 9
# Hipódromo https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.409371399999998,-99.17121259999999&v=20180605&radius=500&limit=10 10
# Hipódromo Condesa https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.409265899999998,-99.1795821&v=20180605&radius=500&limit=10 11
# Roma Norte https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.418322699999997,-99.1625655&v=20180605&radius=500&limit=10 12
# Roma Sur https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4058335,-99.1633037&v=20180605&radius=500&limit=10 13
# Santa María la Ribera https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4484168,-99.1579752&v=20180605&radius=500&limit=10 14
# 150
# 150

# %% [markdown]
# How I got the lists of each feature that I want, I need to put them in a Data Frame. I will call it 'CN_Venues'.

# %%
CN_Venues = pd.DataFrame({"ID" : ID , "Name":Name }) # I can create a new Data Frame with the information from the lists. 
CN_Venues.head()
# Out:
#                          ID                 Name
# 0  5227a6a311d2e49199d6c6b8  Micro Teatro Mexico
# 1  4cd4a81567adf04d75ae2891       Quality Bakery
# 2  52c1d7ef498e4be2b5f785bd                Turin
# 3  505513b9e4b0b914257ee5f2   Postres Buenavista
# 4  4d10192759606dcb4531733e           Carl's Jr.

# %%
CN_Venues.shape
# Out:
# (150, 2)

# %% [markdown]
# So, I need to complete my 'CN_Venues' and get the rating feature. I don´t need the location features for each venue by now.

# %%
M = len(CN_Venues) #define the number of rows in the Data Frame to build a for loop.

# %% [markdown]
# This API call is diferent from the last one. This kind of call is premium. With my account I only have 500. Like the JSON file of recommended venues, I will get a new JSON file with the 'details' endpoint. This the same idea. I need to extract the relevant information. With this kind of call I can get the rating, stats and some other important features. But now, I want the rating feature.

# %%
Rating = []
for k in range(M):
    
    venue_id = '{}'.format(CN_Venues['ID'][k]) # ID 
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
    url
    result = requests.get(url).json()
    
    Rating.append(result['response']['venue']['rating'])#This line extract the rating feature from the JSON file.
    
len(Rating)
# Out:
# 150

# %% [markdown]
# Now, I add the rating column to 'CN_Venues' Data Frame.

# %%
CN_Venues['Rating'] = Rating # It is a easy way to add a new column from a list. 
CN_Venues.head()
# Out:
#                          ID                 Name  Rating
# 0  5227a6a311d2e49199d6c6b8  Micro Teatro Mexico     9.0
# 1  4cd4a81567adf04d75ae2891       Quality Bakery     8.8
# 2  52c1d7ef498e4be2b5f785bd                Turin     8.9
# 3  505513b9e4b0b914257ee5f2   Postres Buenavista     7.8
# 4  4d10192759606dcb4531733e           Carl's Jr.     7.8

# %%
CN_Venues.describe() # This the main information of the Rating column.
# Out:
#            Rating
# count  150.000000
# mean     8.509333
# std      0.379216
# min      7.600000
# 25%      8.300000
# 50%      8.500000
# 75%      8.800000
# max      9.400000

# %% [markdown]
# The 'explore' endpoint make a regular call. I need to get the main categorie of each venue.

# %%
Categories = []
for j in range(len(CN)):
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, CN['Latitude'][j],CN['Longitude'][j], VERSION, radius, LIMIT)
    print(CN['Neighborhood'][j], url , j)
    results = requests.get(url).json()
    for i in range(10):
        Categories.append(results['response']['groups'][0]['items'][i]['venue']['categories'][0]['name'])
        
print(len(Categories))
# Out:
# Buenavista https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.446167000000003,-99.15269609999999&v=20180605&radius=500&limit=10 0
# Centro (Área 1) https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4327,-99.1376&v=20180605&radius=500&limit=10 1
# Centro (Área 2) https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4396,-99.1366&v=20180605&radius=500&limit=10 2
# Centro (Área 3) https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4384,-99.1285&v=20180605&radius=500&limit=10 3
# Centro (Área 4) https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4309,-99.1499&v=20180605&radius=500&limit=10 4
# Centro (Área 5) https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4337,-99.1443&v=20180605&radius=500&limit=10 5
# Centro (Área 6) https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4317,-99.1295&v=20180605&radius=500&limit=10 6
# Centro (Área 7) https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4289,-99.1452&v=20180605&radius=500&limit=10 7
# Centro (Área 8) https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.426,-99.1388&v=20180605&radius=500&limit=10 8
# Condesa https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4148639,-99.176429&v=20180605&radius=500&limit=10 9
# Hipódromo https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.409371399999998,-99.17121259999999&v=20180605&radius=500&limit=10 10
# Hipódromo Condesa https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.409265899999998,-99.1795821&v=20180605&radius=500&limit=10 11
# Roma Norte https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.418322699999997,-99.1625655&v=20180605&radius=500&limit=10 12
# Roma Sur https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4058335,-99.1633037&v=20180605&radius=500&limit=10 13
# Santa María la Ribera https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.4484168,-99.1579752&v=20180605&radius=500&limit=10 14
# 150

# %%
CN_Venues['Main Categorie'] = Categories # Add the new columns from a list. 
CN_Venues.head()
# Out:
#                          ID                 Name  Rating        Main Categorie
# 0  5227a6a311d2e49199d6c6b8  Micro Teatro Mexico     9.0            Public Art
# 1  4cd4a81567adf04d75ae2891       Quality Bakery     8.8                Bakery
# 2  52c1d7ef498e4be2b5f785bd                Turin     8.9           Candy Store
# 3  505513b9e4b0b914257ee5f2   Postres Buenavista     7.8          Dessert Shop
# 4  4d10192759606dcb4531733e           Carl's Jr.     7.8  Fast Food Restaurant

# %% [markdown]
# With this kind of code you can save your CSV from a notebook. Only you need yout notebook token.

# %%
CNV_byRating = CN_Venues.sort_values('Rating',ascending = False) # With this line of code yo can put in order the Data Frame rows by a column.

# %%
CNV_byRating.reset_index(inplace = True)# You can reset the index with the new order. 
CNV_byRating.head(20)
# Out:
#     index                        ID  \
# 0      90  4baec3d5f964a52018d63be3
# 1      50  4b684e6ef964a520d0702be3
# 2     117  4b819a4cf964a520fcb130e3
# 3      55  50ca02bf245f2d4aa8c2aeef
# 4      10  55f476fe498e26410387a491
# 5     120  56d76bac498ecdce6449901f
# 6      80  4d49c47b11a36ea827282b1c
# 7     140  4ccaca619b9346889cb65041
# 8      35  4bfc1626d6f2c9b669b24ec8
# 9     102  4da0921c31a6b60c1a467618
# 10    103  4c1e29deb4e62d7f8ec5dd93
# 11    122  4bcfa325b221c9b68282d2d0
# 12    101  4baef9e0f964a520f0e43be3
# 13    100  4e8771c0be7b72ae72b7dff7
# 14     97  4bad8f31f964a5207c5b3be3
# 15     94  4ce72fce9f776ea824795622
# 16    121  5057c989e4b0db00fbf0ba09
# 17      0  5227a6a311d2e49199d6c6b8
# 18     54  4b0586fff964a5204e7a22e3
# 19     30  512f8b2ce0e2631754ae1db6
#
#                                               Name  Rating  \
# 0                                     Nevería Roxy     9.4
# 1                            Museo de Arte Popular     9.4
# 2   Fondo de Cultura Económica Rosario Castellanos     9.3
# 3                                      El Cardenal     9.3
# 4                          Hotel Historico Central     9.1
# 5                                     Tierra Garat     9.1
# 6                                           Zéfiro     9.1
# 7                                   Kiosco Morisco     9.1
# 8                 Antiguo Colegio de San Ildefonso     9.0
# 9                                    Tout Chocolat     9.0
# 10                                      Mukta Yoga     9.0
# 11           Centro Budista de la Ciudad de México     9.0
# 12                                  Red Tree House     9.0
# 13                          Yoni Shakti Pole Dance     9.0
# 14                                      La Vineria     9.0
# 15                                          Unilac     9.0
# 16                                    Glace Helado     9.0
# 17                             Micro Teatro Mexico     9.0
# 18                                 Alameda Central     8.9
# 19                      Museo Numismático Nacional     8.9
#
#               Main Categorie
# 0             Ice Cream Shop
# 1                 Art Museum
# 2                  Bookstore
# 3         Mexican Restaurant
# 4                      Hotel
# 5                  Cafeteria
# 6         Mexican Restaurant
# 7                      Plaza
# 8                 Art Museum
# 9               Dessert Shop
# 10               Yoga Studio
# 11          Spiritual Center
# 12           Bed & Breakfast
# 13      Gym / Fitness Center
# 14  Mediterranean Restaurant
# 15               Cheese Shop
# 16            Ice Cream Shop
# 17                Public Art
# 18                     Plaza
# 19            History Museum

# %%
CNV_byRating.drop('index',axis=1, inplace = True)#You can drop the column that you don´t need anymore.

# %% [markdown]
# This is the new Data Frame. I called it 'CNV_byRating'. I only show the first eighteen rows. In this slice are the ratings between 9 to 10.

# %%
CNV_byRating.head(18)
# Out:
#                           ID                                            Name  \
# 0   4baec3d5f964a52018d63be3                                    Nevería Roxy
# 1   4b684e6ef964a520d0702be3                           Museo de Arte Popular
# 2   4b819a4cf964a520fcb130e3  Fondo de Cultura Económica Rosario Castellanos
# 3   50ca02bf245f2d4aa8c2aeef                                     El Cardenal
# 4   55f476fe498e26410387a491                         Hotel Historico Central
# 5   56d76bac498ecdce6449901f                                    Tierra Garat
# 6   4d49c47b11a36ea827282b1c                                          Zéfiro
# 7   4ccaca619b9346889cb65041                                  Kiosco Morisco
# 8   4bfc1626d6f2c9b669b24ec8                Antiguo Colegio de San Ildefonso
# 9   4da0921c31a6b60c1a467618                                   Tout Chocolat
# 10  4c1e29deb4e62d7f8ec5dd93                                      Mukta Yoga
# 11  4bcfa325b221c9b68282d2d0           Centro Budista de la Ciudad de México
# 12  4baef9e0f964a520f0e43be3                                  Red Tree House
# 13  4e8771c0be7b72ae72b7dff7                          Yoni Shakti Pole Dance
# 14  4bad8f31f964a5207c5b3be3                                      La Vineria
# 15  4ce72fce9f776ea824795622                                          Unilac
# 16  5057c989e4b0db00fbf0ba09                                    Glace Helado
# 17  5227a6a311d2e49199d6c6b8                             Micro Teatro Mexico
#
#     Rating            Main Categorie
# 0      9.4            Ice Cream Shop
# 1      9.4                Art Museum
# 2      9.3                 Bookstore
# 3      9.3        Mexican Restaurant
# 4      9.1                     Hotel
# 5      9.1                 Cafeteria
# 6      9.1        Mexican Restaurant
# 7      9.1                     Plaza
# 8      9.0                Art Museum
# 9      9.0              Dessert Shop
# 10     9.0               Yoga Studio
# 11     9.0          Spiritual Center
# 12     9.0           Bed & Breakfast
# 13     9.0      Gym / Fitness Center
# 14     9.0  Mediterranean Restaurant
# 15     9.0               Cheese Shop
# 16     9.0            Ice Cream Shop
# 17     9.0                Public Art

# %% [markdown]
# Here is the 'T' Data Frame again.

# %%
T
# Out:
#                       Neighborhood  Postal Code   Latitude  Longitude
# 0           Agrícola Metropolitana        13280  19.290832 -99.052493
# 1   Ampliación José López Portillo        13419  19.313111 -99.027129
# 2           Ampliación La Conchita        13545  19.335036 -98.977113
# 3            Ampliación Los Olivos        13219  19.320556 -99.151701
# 4        Ampliación Santa Catarina        13120  19.318017 -98.963729
# 5                Ampliación Selene        13430  19.284367 -98.991384
# 6             Ampliación Zapotitla        13315  19.335036 -98.977113
# 7                           Cañada        13110  19.335036 -98.977113
# 8                      Chichilaula        13123  19.335036 -98.977113
# 9                          Del Mar        13270  19.320556 -99.151701
# 10                      El Rosario        13540  19.237356 -99.004517
# 11                    El Triángulo        13460  19.285220 -99.016210
# 71                    Santiago Sur        13360  19.284663 -99.030658
# 72                          Selene        13420  19.292310 -99.002443
# 73                         Teozoma        13123  19.335036 -98.977113
# 74                 Tepantitlamilco        13700  19.212212 -98.972732
# 75                   Tierra Blanca        13540  19.237356 -99.004517
# 76           Villa Centroamericana        13278  19.281351 -99.055928
# 77                       Zacatenco        13440  19.294444 -99.021546
# 78                       Zapotitla        13310  19.306475 -99.041657

# %% [markdown]
# I need to get the most popular neighborhoods in the Tláhuac borough.  I will call it 'TN'.

# %%
TN = T[0:1].append(T[9:10]).append(T[31:32]).append(T[34:35]).append(T[37:38]).append(T[61:66]).append(T[78:79])#With the append sentence you can creat a Data Frame by rows instead the columns. 
TN.reset_index(inplace=True)

# %%
TN.drop('index',axis=1,inplace=True)# You can drop the column that you don´t need anymore. 
TN
# Out:
#               Neighborhood  Postal Code   Latitude  Longitude
# 0   Agrícola Metropolitana        13280  19.290832 -99.052493
# 1                  Del Mar        13270  19.320556 -99.151701
# 2              La Nopalera        13220  19.298380 -99.052562
# 3                 La Turba        13250  19.320556 -99.151701
# 4               Los Olivos        13210  19.320556 -99.151701
# 5                Santa Ana        13060  19.267541 -99.008578
# 6         Santa Ana Centro        13300  19.301105 -99.036331
# 7          Santa Ana Norte        13300  19.301105 -99.036331
# 8       Santa Ana Poniente        13300  19.301105 -99.036331
# 9            Santa Ana Sur        13360  19.284663 -99.030658
# 10               Zapotitla        13310  19.306475 -99.041657

# %%
TN.drop([1],axis=0,inplace=True)
TN.reset_index(inplace=True)
TN
# Out:
#    index            Neighborhood  Postal Code   Latitude  Longitude
# 0      0  Agrícola Metropolitana        13280  19.290832 -99.052493
# 1      2             La Nopalera        13220  19.298380 -99.052562
# 2      3                La Turba        13250  19.320556 -99.151701
# 3      4              Los Olivos        13210  19.320556 -99.151701
# 4      5               Santa Ana        13060  19.267541 -99.008578
# 5      6        Santa Ana Centro        13300  19.301105 -99.036331
# 6      7         Santa Ana Norte        13300  19.301105 -99.036331
# 7      8      Santa Ana Poniente        13300  19.301105 -99.036331
# 8      9           Santa Ana Sur        13360  19.284663 -99.030658
# 9     10               Zapotitla        13310  19.306475 -99.041657

# %%
TN.drop('index',axis=1,inplace=True)
TN
# Out:
#              Neighborhood  Postal Code   Latitude  Longitude
# 0  Agrícola Metropolitana        13280  19.290832 -99.052493
# 1             La Nopalera        13220  19.298380 -99.052562
# 2                La Turba        13250  19.320556 -99.151701
# 3              Los Olivos        13210  19.320556 -99.151701
# 4               Santa Ana        13060  19.267541 -99.008578
# 5        Santa Ana Centro        13300  19.301105 -99.036331
# 6         Santa Ana Norte        13300  19.301105 -99.036331
# 7      Santa Ana Poniente        13300  19.301105 -99.036331
# 8           Santa Ana Sur        13360  19.284663 -99.030658
# 9               Zapotitla        13310  19.306475 -99.041657

# %% [markdown]
# I will use the 'explore' endpoint to get almost the same features like in the CN Data Frame.
# The features will be 'Name', 'Categorie' and 'Venue_ID'. I need the Venue_ID in order to use the 'detail' endpoint a get some other features. Now, my radius is more bigger than the CN Data Frame because this is a lower economy than the Cuahtémoc borough. Maybe I wiil get a duplicate information.

# %%
radius = 4000
LIMIT = 50
T_ID = []
T_Name = []
T_Categories = []


for j in range(len(TN)):
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, TN['Latitude'][j],TN['Longitude'][j], VERSION, radius, LIMIT)
    print(TN['Neighborhood'][j], url , j)
    results = requests.get(url).json()
    for i in range(50):
        T_ID.append(results['response']['groups'][0]['items'][i]['venue']['id'])
        T_Name.append(results['response']['groups'][0]['items'][i]['venue']['name'])
        T_Categories.append(results['response']['groups'][0]['items'][i]['venue']['categories'][0]['name'])
                        
        
print(len(T_ID))
print(len(T_Name))
print(len(T_Categories))
# Out:
# Agrícola Metropolitana https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.2908319,-99.0524934&v=20180605&radius=4000&limit=50 0
# La Nopalera https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.2983799,-99.05256225&v=20180605&radius=4000&limit=50 1
# La Turba https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.320556250000006,-99.15170107077653&v=20180605&radius=4000&limit=50 2
# Los Olivos https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.320556250000006,-99.15170107077653&v=20180605&radius=4000&limit=50 3
# Santa Ana https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.267540766666666,-99.00857826666667&v=20180605&radius=4000&limit=50 4
# Santa Ana Centro https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.301105325,-99.03633068333332&v=20180605&radius=4000&limit=50 5
# Santa Ana Norte https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.301105325,-99.03633068333332&v=20180605&radius=4000&limit=50 6
# Santa Ana Poniente https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.301105325,-99.03633068333332&v=20180605&radius=4000&limit=50 7
# Santa Ana Sur https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.284662575,-99.03065815&v=20180605&radius=4000&limit=50 8
# Zapotitla https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.306474899999998,-99.0416573&v=20180605&radius=4000&limit=50 9
# 500
# 500
# 500

# %% [markdown]
# I need a new Data Frame with the new Features. I will call it ' TN_Venues'.

# %%
TN_Venues = pd.DataFrame({'ID':T_ID,'Name':T_Name,'Main Categorie':T_Categories}) # You can create a new Data Frame from the lists. 
TN_Venues.head()
# Out:
#                          ID                                Name  \
# 0  4cae778aeb65b1f760595ccd                        Los Taquitos
# 1  4eaadaf4b803cf1ffb47a0d8          Carnitas La Flor de Cotija
# 2  50521cfbe4b02dee62ca3635  Carnitas Estilo Michoacán El Paisa
# 3  4f20c6d4e4b08ed6b4ca47a2                            Don Cuco
# 4  4f6fe82ee4b07e41f09878a5                           Sushisimo
#
#        Main Categorie
# 0          Taco Place
# 1  Mexican Restaurant
# 2          Taco Place
# 3          Taco Place
# 4    Sushi Restaurant

# %% [markdown]
# I need the latitude and longitude Features. I will get them with the 'explore' endpoint.

# %%
radius = 4000
LIMIT = 50
lat = [] #Lat
lon = [] #Lon



for j in range(len(TN)):
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, TN['Latitude'][j],TN['Longitude'][j], VERSION, radius, LIMIT)
    print(TN['Neighborhood'][j], url , j)
    results = requests.get(url).json()
    for i in range(50):
        lat.append(results['response']['groups'][0]['items'][i]['venue']['location']['lat'])#You can extract the latitude feature.
        lon.append(results['response']['groups'][0]['items'][i]['venue']['location']['lng'])#You can extract the longitude feature.
                 
print(len(lat))
print(len(lon))
# Out:
# Agrícola Metropolitana https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.2908319,-99.0524934&v=20180605&radius=4000&limit=50 0
# La Nopalera https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.2983799,-99.05256225&v=20180605&radius=4000&limit=50 1
# La Turba https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.320556250000006,-99.15170107077653&v=20180605&radius=4000&limit=50 2
# Los Olivos https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.320556250000006,-99.15170107077653&v=20180605&radius=4000&limit=50 3
# Santa Ana https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.267540766666666,-99.00857826666667&v=20180605&radius=4000&limit=50 4
# Santa Ana Centro https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.301105325,-99.03633068333332&v=20180605&radius=4000&limit=50 5
# Santa Ana Norte https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.301105325,-99.03633068333332&v=20180605&radius=4000&limit=50 6
# Santa Ana Poniente https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.301105325,-99.03633068333332&v=20180605&radius=4000&limit=50 7
# Santa Ana Sur https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.284662575,-99.03065815&v=20180605&radius=4000&limit=50 8
# Zapotitla https://api.foursquare.com/v2/venues/explore?client_id=A35JKB4OB3YP5S1IY45IN0TRVEQ34RKQHPYUM5OHP354WPHU&client_secret=S513RXSSCT3GZDABQ4BSJJVULB2U0W23OU1BQTT0I2F1PLTV&ll=19.306474899999998,-99.0416573&v=20180605&radius=4000&limit=50 9
# 500
# 500

# %%
TN_Venues['Latitude'] = lat # I add the new column from the Latitude list
TN_Venues['Longitude'] = lon # I add the new column from the longitude List
TN_Venues.head()
# Out:
#                          ID                                Name  \
# 0  4cae778aeb65b1f760595ccd                        Los Taquitos
# 1  4eaadaf4b803cf1ffb47a0d8          Carnitas La Flor de Cotija
# 2  50521cfbe4b02dee62ca3635  Carnitas Estilo Michoacán El Paisa
# 3  4f20c6d4e4b08ed6b4ca47a2                            Don Cuco
# 4  4f6fe82ee4b07e41f09878a5                           Sushisimo
#
#        Main Categorie   Latitude  Longitude
# 0          Taco Place  19.295809 -99.055430
# 1  Mexican Restaurant  19.294897 -99.057706
# 2          Taco Place  19.287660 -99.050957
# 3          Taco Place  19.291856 -99.055175
# 4    Sushi Restaurant  19.297009 -99.054334

# %% [markdown]
# Now, I know that maybe I could get duplicate values. So, lets check.

# %%
print(len(TN_Venues['Name'].unique()))# With the unique() function you can determinate the non-duplicate values.
sorted(TN_Venues['Name'].unique())
# Out:
# 155
# ['"El Dique"',
#  'Alberca - Asturiano',
#  'Alitas "Las Carbonas"',
#  'Antojitos Don Rafa',
#  'Asadero Charolai',
#  'Barbacoa 2 hermanos',
#  'Barbacoa El Compadre',
#  'Barbacoa Sta Cecilia',
#  'Be Grand Coyoacán',
#  'Beverly Gym',
#  'Birria De Chivo "La Huacana"',
#  'Bosque de Tláhuac',
#  'CENTRO VETERINARIO PAWS',
#  'Caballo Azteca',
#  'Café Punta del Cielo',
#  'Caldos de Gallina "El Pollito"',
#  'Campos de Futbol Tempiluli',
#  'Cancha Molinon',
#  'Cantera PUMAS',
#  'Carnitas Don Gaby',
#  'Carnitas El Cuñadito',
#  'Carnitas Estilo Michoacán El Paisa',
#  'Carnitas La Flor de Cotija',
#  'Carnitas Y Barbacoa "Hermanos Rodriguez"',
#  'Casa del abuelo Cafeteria',
#  'Caution Gym',
#  'Cecina De Yecapixtla',
#  'Centro Asturiano Canchas De Tenis',
#  'Centro Asturiano de México, A. C.',
#  'Centro Cultural Zapotitlán',
#  'Cervecentro Estación 19',
#  'Chocko Churro',
#  'Cielito Querido Cafe',
#  'Crazy Sushi',
#  'Don Cuco',
#  'El PORTAL de la CECINA',
#  'El Pez de Oro',
#  'El Pretexto (Café El Pretexto)',
#  'El Rincón de Peribán',
#  'El Rincón de Tamayo',
#  'El Tacuche Arabe',
#  'El Típico',
#  'El puente',
#  'Estadio Azteca',
#  'Estadio UMA',
#  'Explanada de Tláhuac',
#  'Farmacia Guadalajara',
#  'Faro Tláhuac',
#  'Feria de San Pedro Tláhuac',
#  'Finca Mariela',
#  'Frody - Santa Ursula',
#  'Game Zone',
#  'Gorditas "La Vikina"',
#  'Gym - Asturiano',
#  'Gym fashion fitness',
#  'Hamburguesas Sonoyta',
#  'Helados Josue',
#  'Huaraches Pablo',
#  'Iron Muscle Gym',
#  'La Esperanza',
#  'La Michoacana Espartaco',
#  'La Nopalera',
#  'La Oaxaqueña',
#  'La Oveja Negra',
#  'La Plaza-Tlaltenco',
#  'Las Autenticas al Carbón',
#  'Las Aztecas',
#  'Las Cazuelas Don Jose',
#  'Las Muñecas',
#  'LeCaroz',
#  'Light Food',
#  'Little Caesars Pizza',
#  'Los Pinos Club',
#  'Los Sopes de Chelita y sus muchachas',
#  'Los Taquitos',
#  'Mariscos "Los Jilgueros"',
#  'Mariscos La Güera Del Calpus',
#  'Mariscos Mar Y Sol',
#  'Mariscos Morales Calpus',
#  'Marisqueria Tio Froy',
#  'Mercado De Tlahuac',
#  'Mercado de Tlaltenco',
#  'Mercado de flores Acuexcomatl',
#  'Mi Querido San Luis de las Flores',
#  'Micheladas "El Harry"',
#  'Michoacanísimo Birria de Chivo',
#  'Michoacaníssimo',
#  'Monarca Gym Fitness Club',
#  'Morrison Diner',
#  'Museo Diego Rivera-Anahuacalli',
#  'Natural Club',
#  'Obrador Olimpico 68',
#  'Ocelotl Café',
#  'Old Navy',
#  'Oxxo Nopalera',
#  'PETco',
#  'Palace Rouge',
#  'Paleteria Y Neveria Chely',
#  'Paletería y Nevería Vero',
#  'Pan de Zacatlán, DF',
#  'Papelería, Regalos, Mercería "GuCe"',
#  'Parque Ecológico Los Olivos',
#  'Pasteleria Esperanza Nopalera',
#  'Pizzas & Pastas "De La Torre"',
#  'Pizzas Tutulli La Asunción',
#  'Pizzas Tutulli Reno',
#  'Pizzas Zeus',
#  'Plaza Zapotitlan',
#  'Porco Rosso',
#  'Potencia uma',
#  'Pozole Rey Papatzin',
#  'Pozoleria "Flor de Maíz"',
#  'Pozoleria La Fuente',
#  'Princhelas',
#  'Rapsodia',
#  'Restaurante Bar La Playa',
#  'Rocking Burgers',
#  'SALAMANDRA CAFE GOURMET',
#  'Santa Clara',
#  'Selinna Terraza',
#  'Smart Fit',
#  'Sopes Lupita',
#  'Spiritello',
#  'Starbucks',
#  'Sushisimo',
#  'TAK al Carbón',
#  'Tacos Don Ramirín',
#  'Tacos Dragoncito',
#  'Tacos El Gallo',
#  'Tacos de cecina Mi lindo Zapotitlan',
#  'Tacos el Morelia',
#  'Tacosos El Guero (el Comander )',
#  'Tamales Miramontes',
#  'Tanabata',
#  'Taquearía La Cabañita',
#  'Taqueria Carnitas Chela',
#  'Taqueria El Guero',
#  'Taqueria El Güero',
#  'Taqueria El Principe',
#  'Taqueria pepe',
#  'Taquería La Leyenda',
#  'The Lord Of The Coffee',
#  'Tianguis De Los Jueves!',
#  'Tianguis de Col. Del Mar',
#  'Tianguis de los lunes',
#  'Tortas San Lorenzo',
#  'Trinquete Tulyehualco',
#  'Té Latte Corazón',
#  'Zona Palcos Estadio Azteca',
#  'barbacoa Don Trini',
#  'cross-ruan',
#  'farmacias del ahorro',
#  'las tres lolas',
#  'pescados y mariscos el costeño',
#  'tianguis Selene']

# %%
print(len(TN_Venues['Main Categorie'].unique()))
sorted(TN_Venues['Main Categorie'].unique())
# Out:
# 58
# ['American Restaurant',
#  'Art Museum',
#  'Asian Restaurant',
#  'BBQ Joint',
#  'Bakery',
#  'Bar',
#  'Beer Garden',
#  'Breakfast Spot',
#  'Brewery',
#  'Burger Joint',
#  'Café',
#  'Clothing Store',
#  'Coffee Shop',
#  'College Gym',
#  'Convenience Store',
#  'Donut Shop',
#  'Fair',
#  'Food Stand',
#  'Food Truck',
#  'Football Stadium',
#  'Garden',
#  'General Entertainment',
#  'Gym',
#  'Gym / Fitness Center',
#  'Hobby Shop',
#  'Ice Cream Shop',
#  'Italian Restaurant',
#  'Japanese Restaurant',
#  'Lounge',
#  'Market',
#  'Mexican Restaurant',
#  'Music Venue',
#  'Night Market',
#  'Other Great Outdoors',
#  'Park',
#  'Performing Arts Venue',
#  'Pet Store',
#  'Pharmacy',
#  'Pizza Place',
#  'Plaza',
#  'Pool',
#  'Residential Building (Apartment / Condo)',
#  'Restaurant',
#  'Salad Place',
#  'Seafood Restaurant',
#  'Soccer Field',
#  'Soccer Stadium',
#  'Sports Club',
#  'Stadium',
#  'Stationery Store',
#  'Steakhouse',
#  'Sushi Restaurant',
#  'Taco Place',
#  'Tennis Court',
#  'Thrift / Vintage Store',
#  'Vegetarian / Vegan Restaurant',
#  'Veterinarian',
#  'Wings Joint']

# %% [markdown]
# I have many duplicate values. I can drop the extra values with the 'drop_duplicates' function.
# This function won´t drop only categories, it will drop the duplicate rows.  I will call it 'TN_VenuesU', the new Data Frame.

# %%
TN_VenuesU= TN_Venues.drop_duplicates()
TN_VenuesU.shape# Here is the new shape
# Out:
# (161, 5)

# %% [markdown]
# I didn´t consider the 'likes','dislikes' and 'tipCount' features because in the region is very uncommon  post on facebook the local places that you have visited. But I will get it anyway. Maybe I can use them later. By now, the rating feature is very important. I will use the 'details' endpoint again. The stats is a very important feature, but in this JSON file
# there is not the 'Checkin' key, so the stats feature is not very important here.

# %%
likes = []
dislikes = []
TipCounts = []
Rating = []
for k in range(len(TN_VenuesU)):
    
    venue_id = '{}'.format(TN_VenuesU['ID'][k]) # ID 
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
    url
    result = requests.get(url).json()
    
    likes.append(result['response']['venue']['likes'])
    dislikes.append(result['response']['venue']['dislike'])
    TipCounts.append(result['response']['venue']['stats']['tipCount'])
    Rating.append(result['response']['venue']['rating'])
    
print(len(likes))
print(len(dislikes))
print(len(TipCounts))
print(len(Rating))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-3fc52075d401> in <module>
#      10     result = requests.get(url).json()
#      11
# ---> 12     likes.append(result['response']['venue']['likes'])
#      13     dislikes.append(result['response']['venue']['dislike'])
#      14     TipCounts.append(result['response']['venue']['stats']['tipCount'])
#
# KeyError: 'venue'

# %% [markdown]
# I need to add the new lists to my Data Frame.

# %%
TN_VenuesU['likes'] = likes# You can add a new column from a list with this code.
TN_VenuesU['dislikes'] = dislikes# You can add a new column from a list with this code.
TN_VenuesU['Tip_Counts'] = TipCounts# You can add a new column from a list with this code.
TN_VenuesU['Rating'] = Rating# You can add a new column from a list with this code.
TN_VenuesU.head()

# %%
likes[0]['count']#With this code you can extract all the keys that you forgot.

# %%
Likes = []
for i in range(len(likes)):
    Likes.append(likes[i]['count'])
    
Likes

# %%
TN_VenuesU.drop('likes',axis=1,inplace = True)# I drop the old column
TN_VenuesU['likes'] = Likes # I add the new column
TN_VenuesU.head()

# %% [markdown]
# I saved the last data frame like 'TN_VenuesUC' and then I imported it.

# %%
body = client_30e6154c81ce458e9a81cf92d1db1713.get_object(Bucket='courseracapstone-donotdelete-pr-tjqo81z1sickby',Key='TN_VenuesUC.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

TN_VenuesUC = pd.read_csv(body)
TN_VenuesUC.head()
# Out:
#                          ID                                Name  \
# 0  4cae778aeb65b1f760595ccd                        Los Taquitos
# 1  4eaadaf4b803cf1ffb47a0d8          Carnitas La Flor de Cotija
# 2  50521cfbe4b02dee62ca3635  Carnitas Estilo Michoacán El Paisa
# 3  4f20c6d4e4b08ed6b4ca47a2                            Don Cuco
# 4  4f6fe82ee4b07e41f09878a5                           Sushisimo
#
#        Main Categorie   Latitude  Longitude  dislikes  Tip_Counts  Rating  \
# 0          Taco Place  19.295809 -99.055430     False          37     8.8
# 1  Mexican Restaurant  19.294897 -99.057706     False          13     8.5
# 2          Taco Place  19.287660 -99.050957     False          10     8.2
# 3          Taco Place  19.291856 -99.055175     False          24     8.1
# 4    Sushi Restaurant  19.297009 -99.054334     False          16     8.0
#
#    likes
# 0    102
# 1     32
# 2     11
# 3     68
# 4     35

# %% [markdown]
# I will create the 'A' Data Frame with 'Main Categorie' and 'Rating' feature. I´m going to build the Data Frame with the parameters that I want to do in my analysis.

# %%
A = TN_VenuesUC[['Main Categorie','Rating']]# You can create a new Data Frame with less features. 
B = A.groupby(by= 'Main Categorie').mean()# This line of code allows you to get the rating average of each categorie. 
B
# Out:
#                                             Rating
# Main Categorie
# American Restaurant                       7.600000
# Art Museum                                8.900000
# Asian Restaurant                          7.700000
# BBQ Joint                                 8.066667
# Bakery                                    8.100000
# Bar                                       7.850000
# Beer Garden                               7.850000
# Breakfast Spot                            8.175000
# Brewery                                   7.800000
# Burger Joint                              8.525000
# Café                                      8.033333
# Clothing Store                            7.500000
# Coffee Shop                               7.966667
# College Gym                               8.800000
# Convenience Store                         7.200000
# Donut Shop                                7.300000
# Fair                                      7.200000
# Food Stand                                7.900000
# Food Truck                                8.550000
# Football Stadium                          7.500000
# Garden                                    8.100000
# General Entertainment                     7.100000
# Gym                                       7.520000
# Gym / Fitness Center                      7.620000
# Hobby Shop                                7.100000
# Ice Cream Shop                            8.233333
# Italian Restaurant                        7.600000
# Japanese Restaurant                       7.500000
# Lounge                                    7.400000
# Market                                    8.800000
# Mexican Restaurant                        7.957143
# Music Venue                               8.500000
# Night Market                              7.400000
# Other Great Outdoors                      7.400000
# Park                                      7.700000
# Performing Arts Venue                     8.100000
# Pet Store                                 9.200000
# Pharmacy                                  7.400000
# Pizza Place                               7.800000
# Plaza                                     7.466667
# Pool                                      8.600000
# Residential Building (Apartment / Condo)  8.700000
# Restaurant                                7.900000
# Salad Place                               7.700000
# Seafood Restaurant                        7.655556
# Soccer Field                              7.800000
# Soccer Stadium                            8.500000
# Sports Club                               9.000000
# Stadium                                   7.000000
# Stationery Store                          6.900000
# Steakhouse                                8.600000
# Sushi Restaurant                          8.000000
# Taco Place                                7.961905
# Tennis Court                              8.300000
# Thrift / Vintage Store                    7.100000
# Vegetarian / Vegan Restaurant             7.600000
# Veterinarian                              8.700000
# Wings Joint                               7.950000

# %%
A['1'] = 1 # You can add a numercical column with this line of code. 
B1 = A[['Main Categorie','1']] # the B Data Frame in order to count the categories.
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
B1.head()
# Out:
#        Main Categorie  1
# 0          Taco Place  1
# 1  Mexican Restaurant  1
# 2          Taco Place  1
# 3          Taco Place  1
# 4    Sushi Restaurant  1

# %%
B2 = B1.groupby(by = 'Main Categorie').sum()# With this line of code you can Sum the values with the same feature, in this case 'Main Categorie'
B2
# Out:
#                                            1
# Main Categorie
# American Restaurant                        1
# Art Museum                                 1
# Asian Restaurant                           1
# BBQ Joint                                  3
# Bakery                                     4
# Bar                                        2
# Beer Garden                                2
# Breakfast Spot                             4
# Brewery                                    1
# Burger Joint                               4
# Café                                       3
# Clothing Store                             1
# Coffee Shop                                6
# College Gym                                1
# Convenience Store                          1
# Donut Shop                                 1
# Fair                                       1
# Food Stand                                 1
# Food Truck                                 2
# Football Stadium                           1
# Garden                                     2
# General Entertainment                      1
# Gym                                        5
# Gym / Fitness Center                       5
# Hobby Shop                                 1
# Ice Cream Shop                             6
# Italian Restaurant                         2
# Japanese Restaurant                        1
# Lounge                                     1
# Market                                     1
# Mexican Restaurant                        28
# Music Venue                                1
# Night Market                               1
# Other Great Outdoors                       1
# Park                                       1
# Performing Arts Venue                      1
# Pet Store                                  1
# Pharmacy                                   2
# Pizza Place                                6
# Plaza                                      3
# Pool                                       1
# Residential Building (Apartment / Condo)   1
# Restaurant                                 4
# Salad Place                                1
# Seafood Restaurant                         9
# Soccer Field                               2
# Soccer Stadium                             2
# Sports Club                                1
# Stadium                                    1
# Stationery Store                           1
# Steakhouse                                 1
# Sushi Restaurant                           1
# Taco Place                                21
# Tennis Court                               1
# Thrift / Vintage Store                     1
# Vegetarian / Vegan Restaurant              1
# Veterinarian                               1
# Wings Joint                                2

# %% [markdown]
# I already created the Data frames with the numerical features. I need to merge them.

# %%
B3 = pd.merge(B,B2, on = 'Main Categorie')# With this line of code you can merge Data Frames with one column in common. 
B3.head()
# Out:
#                        Rating  1
# Main Categorie
# American Restaurant  7.600000  1
# Art Museum           8.900000  1
# Asian Restaurant     7.700000  1
# BBQ Joint            8.066667  3
# Bakery               8.100000  4

# %% [markdown]
# ### The most popular venues in the Cuahtémoc borough sorted by rating.

# %%
# I opened the CN Data Frame
body = client_30e6154c81ce458e9a81cf92d1db1713.get_object(Bucket='courseracapstone-donotdelete-pr-tjqo81z1sickby',Key='CNV_byRating.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

CNV_byRating = pd.read_csv(body)
CNV_byRating.head(18)
# Out:
#     index                        ID  \
# 0      90  4baec3d5f964a52018d63be3
# 1      50  4b684e6ef964a520d0702be3
# 2     117  4b819a4cf964a520fcb130e3
# 3      55  50ca02bf245f2d4aa8c2aeef
# 4     129  51ba6ba9498e9bcd16eee9ec
# 5     120  56d76bac498ecdce6449901f
# 6     140  4ccaca619b9346889cb65041
# 7      80  4d49c47b11a36ea827282b1c
# 8      10  55f476fe498e26410387a491
# 9      35  4bfc1626d6f2c9b669b24ec8
# 10    121  5057c989e4b0db00fbf0ba09
# 11    122  4bcfa325b221c9b68282d2d0
# 12      0  5227a6a311d2e49199d6c6b8
# 13    102  4c1e29deb4e62d7f8ec5dd93
# 14    101  4baef9e0f964a520f0e43be3
# 15    100  4e8771c0be7b72ae72b7dff7
# 16     94  4ce72fce9f776ea824795622
# 17     97  4bad8f31f964a5207c5b3be3
#
#                                               Name  Rating  \
# 0                                     Nevería Roxy     9.4
# 1                            Museo de Arte Popular     9.4
# 2   Fondo de Cultura Económica Rosario Castellanos     9.3
# 3                                      El Cardenal     9.3
# 4                     Cachito Mío Quiches & Tartas     9.2
# 5                                     Tierra Garat     9.1
# 6                                   Kiosco Morisco     9.1
# 7                                           Zéfiro     9.1
# 8                          Hotel Historico Central     9.1
# 9                 Antiguo Colegio de San Ildefonso     9.0
# 10                                    Glace Helado     9.0
# 11           Centro Budista de la Ciudad de México     9.0
# 12                             Micro Teatro Mexico     9.0
# 13                                      Mukta Yoga     9.0
# 14                                  Red Tree House     9.0
# 15                          Yoni Shakti Pole Dance     9.0
# 16                                          Unilac     9.0
# 17                                      La Vineria     9.0
#
#               Main Categorie
# 0             Ice Cream Shop
# 1                 Art Museum
# 2                  Bookstore
# 3         Mexican Restaurant
# 4                Coffee Shop
# 5                  Cafeteria
# 6                      Plaza
# 7         Mexican Restaurant
# 8                      Hotel
# 9                 Art Museum
# 10            Ice Cream Shop
# 11          Spiritual Center
# 12                Public Art
# 13               Yoga Studio
# 14           Bed & Breakfast
# 15      Gym / Fitness Center
# 16               Cheese Shop
# 17  Mediterranean Restaurant

# %% [markdown]
# ### The most popular venues in the Tláhuac borough sorted by Rating.

# %% [markdown]
# Here is the Data Frame sorted by Rating

# %%
B3.sort_values('Rating',ascending=False)
# Out:
#                                             Rating   1
# Main Categorie
# Pet Store                                 9.200000   1
# Sports Club                               9.000000   1
# Art Museum                                8.900000   1
# College Gym                               8.800000   1
# Market                                    8.800000   1
# Residential Building (Apartment / Condo)  8.700000   1
# Veterinarian                              8.700000   1
# Steakhouse                                8.600000   1
# Pool                                      8.600000   1
# Food Truck                                8.550000   2
# Burger Joint                              8.525000   4
# Soccer Stadium                            8.500000   2
# Music Venue                               8.500000   1
# Tennis Court                              8.300000   1
# Ice Cream Shop                            8.233333   6
# Breakfast Spot                            8.175000   4
# Bakery                                    8.100000   4
# Garden                                    8.100000   2
# Performing Arts Venue                     8.100000   1
# BBQ Joint                                 8.066667   3
# Café                                      8.033333   3
# Sushi Restaurant                          8.000000   1
# Coffee Shop                               7.966667   6
# Taco Place                                7.961905  21
# Mexican Restaurant                        7.957143  28
# Wings Joint                               7.950000   2
# Food Stand                                7.900000   1
# Restaurant                                7.900000   4
# Bar                                       7.850000   2
# Beer Garden                               7.850000   2
# Pizza Place                               7.800000   6
# Brewery                                   7.800000   1
# Soccer Field                              7.800000   2
# Asian Restaurant                          7.700000   1
# Park                                      7.700000   1
# Salad Place                               7.700000   1
# Seafood Restaurant                        7.655556   9
# Gym / Fitness Center                      7.620000   5
# Vegetarian / Vegan Restaurant             7.600000   1
# Italian Restaurant                        7.600000   2
# American Restaurant                       7.600000   1
# Gym                                       7.520000   5
# Clothing Store                            7.500000   1
# Japanese Restaurant                       7.500000   1
# Football Stadium                          7.500000   1
# Plaza                                     7.466667   3
# Other Great Outdoors                      7.400000   1
# Night Market                              7.400000   1
# Pharmacy                                  7.400000   2
# Lounge                                    7.400000   1
# Donut Shop                                7.300000   1
# Convenience Store                         7.200000   1
# Fair                                      7.200000   1
# General Entertainment                     7.100000   1
# Thrift / Vintage Store                    7.100000   1
# Hobby Shop                                7.100000   1
# Stadium                                   7.000000   1
# Stationery Store                          6.900000   1

# %% [markdown]
# ### The most popular venues in the Tláhuac borough sorted by number of venues.

# %% [markdown]
# Here is the Data Frame sorted by number of venues

# %%
B3.sort_values('1',ascending=False)
# Out:
#                                             Rating   1
# Main Categorie
# Mexican Restaurant                        7.957143  28
# Taco Place                                7.961905  21
# Seafood Restaurant                        7.655556   9
# Pizza Place                               7.800000   6
# Ice Cream Shop                            8.233333   6
# Coffee Shop                               7.966667   6
# Gym / Fitness Center                      7.620000   5
# Gym                                       7.520000   5
# Breakfast Spot                            8.175000   4
# Restaurant                                7.900000   4
# Bakery                                    8.100000   4
# Burger Joint                              8.525000   4
# Café                                      8.033333   3
# BBQ Joint                                 8.066667   3
# Plaza                                     7.466667   3
# Garden                                    8.100000   2
# Soccer Field                              7.800000   2
# Italian Restaurant                        7.600000   2
# Soccer Stadium                            8.500000   2
# Wings Joint                               7.950000   2
# Pharmacy                                  7.400000   2
# Beer Garden                               7.850000   2
# Bar                                       7.850000   2
# Food Truck                                8.550000   2
# Stadium                                   7.000000   1
# Sports Club                               9.000000   1
# Stationery Store                          6.900000   1
# Steakhouse                                8.600000   1
# Sushi Restaurant                          8.000000   1
# Tennis Court                              8.300000   1
# Thrift / Vintage Store                    7.100000   1
# Vegetarian / Vegan Restaurant             7.600000   1
# Salad Place                               7.700000   1
# Residential Building (Apartment / Condo)  8.700000   1
# Pool                                      8.600000   1
# Veterinarian                              8.700000   1
# American Restaurant                       7.600000   1
# Pet Store                                 9.200000   1
# Football Stadium                          7.500000   1
# Asian Restaurant                          7.700000   1
# Brewery                                   7.800000   1
# Clothing Store                            7.500000   1
# College Gym                               8.800000   1
# Convenience Store                         7.200000   1
# Donut Shop                                7.300000   1
# Fair                                      7.200000   1
# Food Stand                                7.900000   1
# General Entertainment                     7.100000   1
# Performing Arts Venue                     8.100000   1
# Hobby Shop                                7.100000   1
# Japanese Restaurant                       7.500000   1
# Lounge                                    7.400000   1
# Art Museum                                8.900000   1
# Music Venue                               8.500000   1
# Night Market                              7.400000   1
# Other Great Outdoors                      7.400000   1
# Park                                      7.700000   1
# Market                                    8.800000   1

# %% [markdown]
# ### The last step. Can I get relevant information with the last Data Frames?

# %% [markdown]
# #### Choosing the Mexican Restaurant categorie.

# %% [markdown]
# I will try to get conclusions with the Data Frames.
#
# - A map with Marks.
# - A Multiple Linear Regression Model with two Features.

# %%
body = client_30e6154c81ce458e9a81cf92d1db1713.get_object(Bucket='courseracapstone-donotdelete-pr-tjqo81z1sickby',Key='TN_VenuesUC.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

TN_VenuesUC = pd.read_csv(body)
TN_VenuesUC.head()
# Out:
#                          ID                                Name  \
# 0  4cae778aeb65b1f760595ccd                        Los Taquitos
# 1  4eaadaf4b803cf1ffb47a0d8          Carnitas La Flor de Cotija
# 2  50521cfbe4b02dee62ca3635  Carnitas Estilo Michoacán El Paisa
# 3  4f20c6d4e4b08ed6b4ca47a2                            Don Cuco
# 4  4f6fe82ee4b07e41f09878a5                           Sushisimo
#
#        Main Categorie   Latitude  Longitude  dislikes  Tip_Counts  Rating  \
# 0          Taco Place  19.295809 -99.055430     False          37     8.8
# 1  Mexican Restaurant  19.294897 -99.057706     False          13     8.5
# 2          Taco Place  19.287660 -99.050957     False          10     8.2
# 3          Taco Place  19.291856 -99.055175     False          24     8.1
# 4    Sushi Restaurant  19.297009 -99.054334     False          16     8.0
#
#    likes
# 0    102
# 1     32
# 2     11
# 3     68
# 4     35

# %%
M = TN_VenuesUC.sort_values('Main Categorie')
M.reset_index(inplace=True)

M
# Out:
#      index                        ID  \
# 0       44  4cc8d92dd54fa1cd32433429
# 1       59  4b058700f964a520a27a22e3
# 2       13  5430c4a3498ed5e70b974b28
# 3       88  563bc7fecd101b419be07a98
# 4       28  55c639f5498e1fc7dc622c6d
# 5      147  4f66618ce4b087553eac68c9
# 6       52  4f6f6d46e4b0f8396759e4f9
# 7       96  4cfe72668e3b8eec3235c293
# 8       10  4dc9f18445dd194399fff405
# 9       50  52799a5d498e898cef62347c
# 10      63  4dab3b3493a04642f0913e8e
# 11     121  54922f39498ead6e0c03522c
# 12      43  550617e4498e36719a08fd87
# 13      79  4c952b13f244b1f7c043291d
# 14     101  5534fc1c498e3b25a05d4c4c
# 15      83  571956b2498ed30e80c49183
# 16      22  5217d3632fc631f8ffebea07
# 17     153  56d3a90ccd101bd7e49c83af
# 18      18  51c9d7db498e72db870d7a36
# 19      87  58f916022bf9a95e3554ccde
# 20      99  4ee558d3f9abfc722786054f
# 21     111  4eae0257b8f765aba1931426
# 22      84  5160cf93e4b08465e9436359
# 23     100  55b97c6e498ed02a75926dee
# 24     105  4f22e9fc7716589cee0d61d5
# 25       9  50e90689e4b044bde5286754
# 26     118  564685e3498ebb7b5246d670
# 27      25  557480cd498ea7cb089d893e
# 28     158  4f8901dee4b05ae888770b9d
# 29      90  50821544e4b0bf87c0398372
# 0                        Hamburguesas Sonoyta
# 1              Museo Diego Rivera-Anahuacalli
# 2                                    Tanabata
# 3                                 Porco Rosso
# 4                             Huaraches Pablo
# 5                            Asadero Charolai
# 6                                     LeCaroz
# 7                         Pan de Zacatlán, DF
# 8               Pasteleria Esperanza Nopalera
# 9                                La Esperanza
# 10                    Cervecentro Estación 19
# 11                             La Oveja Negra
# 12                      Micheladas "El Harry"
# 13                                Las Aztecas
# 14                       Cielito Querido Cafe
# 15             El Pretexto (Café El Pretexto)
# 16                        Pizzas Tutulli Reno
# 17                              Chocko Churro
# 18                                 Princhelas
# 19                            Rocking Burgers
# 20                            Rocking Burgers
# 21                   Las Autenticas al Carbón
# 22                             Morrison Diner
# 23                       Café Punta del Cielo
# 24                        El Rincón de Tamayo
# 25                     The Lord Of The Coffee
# 26                                   Old Navy
# 27                  Casa del abuelo Cafeteria
# 28                    SALAMANDRA CAFE GOURMET
# 29                                  Starbucks
# 30                               Ocelotl Café
# 31                           Té Latte Corazón
# 32                                  Starbucks
# 33                              Cantera PUMAS
# 34                              Oxxo Nopalera
# 35                               La Esperanza
# 36                 Feria de San Pedro Tláhuac
# 37                   Tianguis de Col. Del Mar
# 38                         Tamales Miramontes
# 39                    Tianguis De Los Jueves!
# 40                                Estadio UMA
# 41              Mercado de flores Acuexcomatl
# 42          Mi Querido San Luis de las Flores
# 43                 Centro Cultural Zapotitlán
# 44                   Monarca Gym Fitness Club
# 45                               Palace Rouge
# 46                            Iron Muscle Gym
# 47                             Los Pinos Club
# 48                                Beverly Gym
# 49                                  Smart Fit
# 50                        Gym fashion fitness
# 51                                 cross-ruan
# 52                            Gym - Asturiano
# 53                                Caution Gym
# 54                                  Game Zone
# 55                              Helados Josue
# 56                    La Michoacana Espartaco
# 57                   Paletería y Nevería Vero
# 58                  Paleteria Y Neveria Chely
# 59                                Santa Clara
# 60                       Frody - Santa Ursula
# 61              Pizzas & Pastas "De La Torre"
# 62                                 Spiritello
# 63                                Crazy Sushi
# 64                              Finca Mariela
# 65                      Tianguis de los lunes
# 66                   Restaurante Bar La Playa
# 67             Michoacanísimo Birria de Chivo
# 68                           El Tacuche Arabe
# 69                              Taqueria pepe
# 70                        Pozole Rey Papatzin
# 71                       El Rincón de Peribán
# 72                       Barbacoa El Compadre
# 73                            Michoacaníssimo
# 74                         Mercado De Tlahuac
# 75                       Mercado de Tlaltenco
# 76                 Carnitas La Flor de Cotija
# 77                         Antojitos Don Rafa
# 78                   Pozoleria "Flor de Maíz"
# 79                               La Oaxaqueña
# 80                         Tortas San Lorenzo
# 81                      Las Cazuelas Don Jose
# 82       Los Sopes de Chelita y sus muchachas
# 83                       Gorditas "La Vikina"
# 84                            Huaraches Pablo
# 85                             las tres lolas
# 86   Carnitas Y Barbacoa "Hermanos Rodriguez"
# 87                             Caballo Azteca
# 88                                  El puente
# 89                        Pozoleria La Fuente
# 90                        Taquería La Leyenda
# 91                                  El Típico
# 92               Birria De Chivo "La Huacana"
# 93                    Taqueria Carnitas Chela
# 94                               Potencia uma
# 95                                La Nopalera
# 96                          Bosque de Tláhuac
# 97                Parque Ecológico Los Olivos
# 98                               Faro Tláhuac
# 99                                      PETco
# 100                      Farmacia Guadalajara
# 101                      farmacias del ahorro
# 102                               Pizzas Zeus
# 103                      Little Caesars Pizza
# 104                      Little Caesars Pizza
# 105                      Little Caesars Pizza
# 106                                  Rapsodia
# 107                Pizzas Tutulli La Asunción
# 108                      Explanada de Tláhuac
# 109                        La Plaza-Tlaltenco
# 110                          Plaza Zapotitlan
# 111                       Alberca - Asturiano
# 112                         Be Grand Coyoacán
# 113                      Carnitas El Cuñadito
# 114                           Selinna Terraza
# 115                    El PORTAL de la CECINA
# 116            Caldos de Gallina "El Pollito"
# 117                                Light Food
# 118              Mariscos La Güera Del Calpus
# 119                                "El Dique"
# 120                      Marisqueria Tio Froy
# 121                        Mariscos Mar Y Sol
# 122            pescados y mariscos el costeño
# 123                  Mariscos "Los Jilgueros"
# 124                         Mariscos chivella
# 125                   Mariscos Morales Calpus
# 126                             El Pez de Oro
# 127                            Cancha Molinon
# 128                Campos de Futbol Tempiluli
# 129                Zona Palcos Estadio Azteca
# 130                            Estadio Azteca
# 131         Centro Asturiano de México, A. C.
# 132                     Trinquete Tulyehualco
# 133       Papelería, Regalos, Mercería "GuCe"
# 134                       Obrador Olimpico 68
# 135                                 Sushisimo
# 136                         Taqueria El Güero
# 137                            Tacos El Gallo
# 138                              Los Taquitos
# 139                         Carnitas Don Gaby
# 140        Carnitas Estilo Michoacán El Paisa
# 141                                  Don Cuco
# 142                         Tacos Don Ramirín
# 143       Tacos de cecina Mi lindo Zapotitlan
# 144           Tacosos El Guero (el Comander )
# 145                         Taqueria El Guero
# 146                       Barbacoa 2 hermanos
# 147                        barbacoa Don Trini
# 148                          Tacos Dragoncito
# 149                      Barbacoa Sta Cecilia
# 150                     Taquearía La Cabañita
# 151                      Taqueria El Principe
# 152                              Sopes Lupita
# 153                               Las Muñecas
# 154                          Tacos el Morelia
# 155                      Cecina De Yecapixtla
# 156                             TAK al Carbón
# 157         Centro Asturiano Canchas De Tenis
# 158                           tianguis Selene
# 159                              Natural Club
# 160                   CENTRO VETERINARIO PAWS
# 161                     Alitas "Las Carbonas"
# 162           Mishalitas W&B  Cars&Biker Club
#
#                                Main Categorie   Latitude  Longitude  dislikes  \
# 0                         American Restaurant  19.305319 -99.061687     False
# 1                                  Art Museum  19.322780 -99.143796     False
# 2                            Asian Restaurant  19.296375 -99.055585     False
# 3                                   BBQ Joint  19.337971 -99.147925     False
# 4                                   BBQ Joint  19.293934 -99.041393     False
# 5                                   BBQ Joint  19.235521 -98.993668     False
# 6                                      Bakery  19.309934 -99.069777     False
# 7                                      Bakery  19.337454 -99.150182     False
# 8                                      Bakery  19.295850 -99.054548     False
# 9                                      Bakery  19.317128 -99.074196     False
# 10                                        Bar  19.314132 -99.153655     False
# 11                                        Bar  19.273791 -99.007818     False
# 12                                Beer Garden  19.292025 -99.067214     False
# 13                                Beer Garden  19.309411 -99.153920     False
# 14                             Breakfast Spot  19.309214 -99.134095     False
# 15                             Breakfast Spot  19.319119 -99.134474     False
# 135                          Sushi Restaurant  19.297009 -99.054334     False
# 136                                Taco Place  19.295659 -99.007717     False
# 137                                Taco Place  19.291224 -99.032616     False
# 138                                Taco Place  19.295809 -99.055430     False
# 139                                Taco Place  19.291871 -99.016743     False
# 140                                Taco Place  19.287660 -99.050957     False
# 141                                Taco Place  19.291856 -99.055175     False
# 142                                Taco Place  19.304741 -99.052217     False
# 143                                Taco Place  19.296828 -99.033262     False
# 144                                Taco Place  19.290438 -99.036082     False
# 145                                Taco Place  19.296491 -99.032536     False
# 146                                Taco Place  19.294220 -99.061706     False
# 147                                Taco Place  19.296552 -99.054198     False
# 148                                Taco Place  19.303919 -99.047973     False
# 149                                Taco Place  19.278711 -99.005889     False
# 150                                Taco Place  19.324644 -99.063170     False
# 151                                Taco Place  19.324730 -99.154569     False
# 152                                Taco Place  19.319059 -99.142929     False
# 153                                Taco Place  19.322231 -99.163578     False
# 154                                Taco Place  19.319564 -99.134558     False
# 155                                Taco Place  19.267399 -99.005925     False
# 156                                Taco Place  19.279802 -99.001279     False
# 157                              Tennis Court  19.316322 -99.144542     False
# 158                    Thrift / Vintage Store  19.286946 -98.999255     False
# 159             Vegetarian / Vegan Restaurant  19.284992 -98.999856     False
# 160                              Veterinarian  19.308419 -99.135145     False
# 161                               Wings Joint  19.326061 -99.034420     False
# 162                               Wings Joint  19.299668 -99.071588     False
#
#      Tip_Counts  Rating  likes
# 0            10     7.6     16
# 1           149     8.9    825
# 2             7     7.7     14
# 3           258     8.7    813
# 4             0     7.6      7
# 5             4     7.9      6
# 6             1     7.7     15
# 7            58     8.4    192
# 8             6     7.9     36
# 9             9     8.4     79
# 10          150     8.5    599
# 11            1     7.2     11
# 12            3     7.5     11
# 13           65     8.2    321
# 14            3     8.6     21
# 15            3     8.6     10
# 16            5     8.2     26
# 17            1     7.3      6
# 18            8     7.8     28
# 19           48     8.7    148
# 20          312     8.8    682
# 21           11     8.2     22
# 22           42     8.4     80
# 23           11     8.3     69
# 24            4     7.9      8
# 25           10     7.9     39
# 26            0     7.5      8
# 27            3     7.7      8
# 28           17     7.3     25
# 29          182     8.5    997
# 30            3     8.2     11
# 31           14     8.8     37
# 32            3     7.3      6
# 33           34     8.8    225
# 34            0     7.2      9
# 35            0     7.3     17
# 36           10     7.2     19
# 37            2     7.9      7
# 38            1     8.6     13
# 39            7     8.5     95
# 40            0     7.5      8
# 41            5     8.6     26
# 42           12     7.6     29
# 43            2     7.1      9
# 44            5     7.5     24
# 45            0     6.7      8
# 46            2     7.7     22
# 47            0     8.1     10
# 48            4     7.6     13
# 49            2     7.3      6
# 50            6     7.2     17
# 51            1     7.3      9
# 52            6     9.0    139
# 53           12     7.3     33
# 54            7     7.1      5
# 55            3     8.0      6
# 56           11     8.3     54
# 57            4     8.1     11
# 58            2     7.7     13
# 59           10     8.8     72
# 60           46     8.5    150
# 61            3     6.8      8
# 62           53     8.4    135
# 63           27     7.5     37
# 64            4     7.4     13
# 65            2     8.8     19
# 66           29     7.3     47
# 67           16     8.3     77
# 68          119     8.2    332
# 69            2     8.6     12
# 70           50     8.6    159
# 71          173     8.2    580
# 72            4     8.6     19
# 73          774     9.1   2670
# 74           10     7.6     48
# 75            0     7.5     13
# 76           13     8.5     32
# 77            4     8.5      9
# 78           20     8.0     49
# 79            1     7.7     15
# 80            4     7.7      9
# 81           11     8.0     24
# 82            3     7.4     16
# 83          209     8.9    783
# 84            7     7.9     35
# 85            2     7.4      5
# 86            2     7.6      8
# 87           16     7.9     38
# 88           10     6.8     17
# 89          163     8.6    379
# 90            6     8.5     17
# 91            3     7.5     13
# 92            4     6.5     13
# 93            3     7.4     11
# 94            1     8.5     14
# 95           10     7.4    103
# 96           60     7.4    186
# 97            6     7.7     36
# 98            8     8.1     43
# 99           97     9.2    757
# 100           0     7.5      9
# 101           0     7.3      8
# 102           5     8.5     12
# 103           1     7.5      4
# 104           4     7.9     23
# 105           0     7.2      4
# 106           7     8.5     12
# 107           4     7.2      7
# 108          31     7.1    118
# 109           2     7.7      8
# 110           2     7.6      8
# 111          11     8.6     38
# 112           9     8.7     56
# 113           0     8.3      8
# 114          42     8.4    146
# 115           1     7.3      9
# 116          22     7.6     63
# 117           5     7.7      8
# 118          16     8.5     24
# 119          46     8.1     94
# 120          81     8.3    191
# 121           4     7.4      9
# 122           4     7.4     14
# 123           1     7.0      7
# 124           1     6.7      5
# 125          26     7.5     84
# 126           3     8.0     12
# 127           1     8.6     25
# 128           1     7.0     23
# 129          27     8.5    462
# 130         618     8.5   7999
# 131         118     9.0    661
# 132           4     7.0     10
# 133          94     6.9      6
# 134           5     8.6     16
# 135          16     8.0     35
# 136           3     7.4     15
# 137           1     7.1     11
# 138          37     8.8    102
# 139           4     7.8      5
# 140          10     8.2     11
# 141          24     8.1     68
# 142           4     8.4     11
# 143           2     8.7     12
# 144           1     8.1     11
# 145           4     8.6     15
# 146           2     7.5     19
# 147           6     7.3     14
# 148           8     7.5     12
# 149           1     7.0     12
# 150           7     8.0      8
# 151          20     8.5     63
# 152          91     8.8    229
# 153         247     8.2    650
# 154          50     8.4    160
# 155           2     7.4      6
# 156           3     7.4      6
# 157           2     8.3     19
# 158           1     7.1      8
# 159          27     7.6     70
# 160           5     8.7     19
# 161           6     8.3      7
# 162           0     7.6      7

# %% [markdown]
# Now, I want a Data Frame with Mexican Restaurant categorie only. I will call it 'Mexican Restaurant'

# %%
M.drop('index',axis=1,inplace=True)
Mexican_Restaurant=M[66:94]
Mexican_Restaurant
# Out:
#                           ID                                      Name  \
# 66  4c9e462ad3c2b60c74a6c9bc                  Restaurante Bar La Playa
# 67  56db1c2a498e0bcb2b9d8305            Michoacanísimo Birria de Chivo
# 68  4c2e4651e307d13a354a0fda                          El Tacuche Arabe
# 69  4fd80217e4b09bbdac9567c0                             Taqueria pepe
# 70  5053544be4b0feb2992ebf43                       Pozole Rey Papatzin
# 71  4e078dd68877394591e7101a                      El Rincón de Peribán
# 72  51894113498e3c5f2d509363                      Barbacoa El Compadre
# 73  4e0248cdd4c0836163de5db6                           Michoacaníssimo
# 74  4c55fd3619160f47865617b4                        Mercado De Tlahuac
# 92  Mexican Restaurant  19.266900 -99.006330     False           4     6.5
# 93  Mexican Restaurant  19.292778 -99.041229     False           3     7.4
#
#     likes
# 66     47
# 67     77
# 68    332
# 69     12
# 70    159
# 71    580
# 72     19
# 73   2670
# 74     48
# 75     13
# 76     32
# 77      9
# 78     49
# 79     15
# 80      9
# 81     24
# 82     16
# 83    783
# 84     35
# 85      5
# 86      8
# 87     38
# 88     17
# 89    379
# 90     17
# 91     13
# 92     13
# 93     11

# %%
Mexican_Restaurant.reset_index(inplace=True)
Mexican_Restaurant.drop('index',axis=1,inplace=True)

Mexican_Restaurant
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#                           ID                                      Name  \
# 0   4c9e462ad3c2b60c74a6c9bc                  Restaurante Bar La Playa
# 1   56db1c2a498e0bcb2b9d8305            Michoacanísimo Birria de Chivo
# 2   4c2e4651e307d13a354a0fda                          El Tacuche Arabe
# 3   4fd80217e4b09bbdac9567c0                             Taqueria pepe
# 4   5053544be4b0feb2992ebf43                       Pozole Rey Papatzin
# 5   4e078dd68877394591e7101a                      El Rincón de Peribán
# 6   51894113498e3c5f2d509363                      Barbacoa El Compadre
# 7   4e0248cdd4c0836163de5db6                           Michoacaníssimo
# 8   4c55fd3619160f47865617b4                        Mercado De Tlahuac
# 9   51605cede4b0db8cd97d73fd                      Mercado de Tlaltenco
# 10  4eaadaf4b803cf1ffb47a0d8                Carnitas La Flor de Cotija
# 11  5234af9c11d20ca115b10653                        Antojitos Don Rafa
# 12  55cfb1d9498e869b7a27d530                  Pozoleria "Flor de Maíz"
# 13  5338a7e5498e344d64d94abd                              La Oaxaqueña
# 14  50f1f386e4b036c5cb37d7d7                        Tortas San Lorenzo
# 15  4fb52c7de4b0ccfe26dc7426                     Las Cazuelas Don Jose
# 16  501d6440e4b0efa1ebcd85b5      Los Sopes de Chelita y sus muchachas
# 17  4d5194a79b27721e5e48b946                      Gorditas "La Vikina"
# 18  4f36ee15e4b0a67febbf5cf5                           Huaraches Pablo
# 19  53260553498e83d42bba22ae                            las tres lolas
# 20  5016cd08e4b0e3a6f5a8c267  Carnitas Y Barbacoa "Hermanos Rodriguez"
# 21  4dd968618877f115101a0358                            Caballo Azteca
# 22  4fb7c6b2e4b0e6d290278b24                                 El puente
# 23  4c00113a92a6c9283c9743e2                       Pozoleria La Fuente
# 24  5093dd20e4b08ccc26ed7700                       Taquería La Leyenda
# 25  4fd01a84e4b05d15272f1caf                                 El Típico
# 26  4fede1d8e4b0660371ab5d4f              Birria De Chivo "La Huacana"
# 27  502daaaee4b0543f9852f8cd                   Taqueria Carnitas Chela
#
#         Main Categorie   Latitude  Longitude  dislikes  Tip_Counts  Rating  \
# 0   Mexican Restaurant  19.266056 -99.006937     False          29     7.3
# 1   Mexican Restaurant  19.311864 -99.161570     False          16     8.3
# 2   Mexican Restaurant  19.318973 -99.134005     False         119     8.2
# 3   Mexican Restaurant  19.338141 -99.046457     False           2     8.6
# 4   Mexican Restaurant  19.313299 -99.166447     False          50     8.6
# 5   Mexican Restaurant  19.314076 -99.167681     False         173     8.2
# 6   Mexican Restaurant  19.310040 -99.162288     False           4     8.6
# 7   Mexican Restaurant  19.312087 -99.161453     False         774     9.1
# 8   Mexican Restaurant  19.268668 -99.004887     False          10     7.6
# 9   Mexican Restaurant  19.295685 -99.014600     False           0     7.5
# 10  Mexican Restaurant  19.294897 -99.057706     False          13     8.5
# 11  Mexican Restaurant  19.296097 -99.065530     False           4     8.5
# 12  Mexican Restaurant  19.298052 -99.041739     False          20     8.0
# 13  Mexican Restaurant  19.291106 -99.033613     False           1     7.7
# 14  Mexican Restaurant  19.301781 -99.052661     False           4     7.7
# 15  Mexican Restaurant  19.304563 -99.060671     False          11     8.0
# 16  Mexican Restaurant  19.297169 -99.054028     False           3     7.4
# 17  Mexican Restaurant  19.309507 -99.141069     False         209     8.9
# 18  Mexican Restaurant  19.288643 -99.006827     False           7     7.9
# 19  Mexican Restaurant  19.295698 -99.021211     False           2     7.4
# 20  Mexican Restaurant  19.259260 -99.027361     False           2     7.6
# 21  Mexican Restaurant  19.288916 -99.013333     False          16     7.9
# 22  Mexican Restaurant  19.275951 -99.006189     False          10     6.8
# 23  Mexican Restaurant  19.313827 -99.159168     False         163     8.6
# 24  Mexican Restaurant  19.311826 -99.153091     False           6     8.5
# 25  Mexican Restaurant  19.269147 -99.005850     False           3     7.5
# 26  Mexican Restaurant  19.266900 -99.006330     False           4     6.5
# 27  Mexican Restaurant  19.292778 -99.041229     False           3     7.4
#
#     likes
# 0      47
# 1      77
# 2     332
# 3      12
# 4     159
# 5     580
# 6      19
# 7    2670
# 8      48
# 9      13
# 10     32
# 11      9
# 12     49
# 13     15
# 14      9
# 15     24
# 16     16
# 17    783
# 18     35
# 19      5
# 20      8
# 21     38
# 22     17
# 23    379
# 24     17
# 25     13
# 26     13
# 27     11

# %%
Mexican_Restaurant.describe()#With this line of code you can obtain the main numerical info about your DataFrame.
# Out:
#         Latitude  Longitude  Tip_Counts     Rating        likes
# count  28.000000  28.000000   28.000000  28.000000    28.000000
# mean   19.296607 -99.070497   59.214286   7.957143   193.928571
# std     0.018850   0.063055  151.556213   0.626825   520.827613
# min    19.259260 -99.167681    0.000000   6.500000     5.000000
# 25%    19.288848 -99.144074    3.000000   7.500000    13.000000
# 50%    19.296633 -99.049559    8.500000   7.950000    21.500000
# 75%    19.311836 -99.014284   22.250000   8.500000    56.000000
# max    19.338141 -99.004887  774.000000   9.100000  2670.000000

# %% [markdown]
# I need to order the Data Frame by Rating in order to create a Folium Map.

# %%
MR = Mexican_Restaurant.sort_values('Rating',ascending=False)
MR.reset_index(inplace=True)
MR.drop('index',axis=1,inplace=True)
MR
# Out:
#                           ID                                      Name  \
# 0   4e0248cdd4c0836163de5db6                           Michoacaníssimo
# 1   4d5194a79b27721e5e48b946                      Gorditas "La Vikina"
# 2   4fd80217e4b09bbdac9567c0                             Taqueria pepe
# 3   5053544be4b0feb2992ebf43                       Pozole Rey Papatzin
# 4   51894113498e3c5f2d509363                      Barbacoa El Compadre
# 5   4c00113a92a6c9283c9743e2                       Pozoleria La Fuente
# 6   5234af9c11d20ca115b10653                        Antojitos Don Rafa
# 24  Mexican Restaurant  19.297169 -99.054028     False           3     7.4
# 25  Mexican Restaurant  19.266056 -99.006937     False          29     7.3
# 26  Mexican Restaurant  19.275951 -99.006189     False          10     6.8
# 27  Mexican Restaurant  19.266900 -99.006330     False           4     6.5
#
#     likes
# 0    2670
# 1     783
# 2      12
# 3     159
# 4      19
# 5     379
# 6       9
# 7      17
# 8      32
# 9      77
# 10    332
# 11    580
# 12     24
# 13     49
# 14     35
# 15     38
# 16     15
# 17      9
# 18     48
# 19      8
# 20     13
# 21     13
# 22     11
# 23      5
# 24     16
# 25     47
# 26     17
# 27     13

# %% [markdown]
# With Folium I can create a map with marks.

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium

print('Folium installed and imported!')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1g             |       h516909a_1         2.1 MB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.1.0-py_1        conda-forge
#     branca:          0.4.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:         2020.6.20-py36_0              --> 2020.6.20-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_1        conda-forge
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates: 2020.6.24-0                   --> 2020.6.20-hecda079_0     conda-forge
#
#
# Downloading and Extracting Packages
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# ca-certificates-2020 | 145 KB    | ##################################### | 100%
# certifi-2020.6.20    | 151 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed and imported!

# %% [markdown]
# I need to create the base map of Tláhuac. I can get it  with these lines of code.

# %%
latitude = 19.28689
longitude = -99.00507

MexicanR_map = folium.Map(location=[latitude, longitude], zoom_start=15)
MexicanR_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# I'm going to create a map with rating distribution that I got  with the describe function.

# %% [markdown]
# - Yellow: (8.5 - 10)
# - Green: (7.9 - 8.4)
# - Blue: (7.5 - 7.8)
# - Red : (0 - 7.4)

# %%
# instantiate a feature group for the incidents in the dataframe
Restaurants = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(MR['Latitude'][0:9], MR['Longitude'][0:9]):
    Restaurants.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='yellow',
            fill_opacity=0.6
        )
    )

# add pop-up text to each marker on the map
latitudes = list(MR['Latitude'][0:9])
longitudes = list(MR['Longitude'][0:9])
labels = list(MR['Name'][0:9])

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(MexicanR_map)    
    
# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(MR['Latitude'][9:16], MR['Longitude'][9:16]):
    Restaurants.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='green',
            fill=True,
            fill_color='green',
            fill_opacity=0.6
        )
    )

# add pop-up text to each marker on the map
latitudes = list(MR['Latitude'][9:16])
longitudes = list(MR['Longitude'][9:16])
labels = list(MR['Name'][9:16])

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(MexicanR_map) 
    
    
# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(MR['Latitude'][16:22], MR['Longitude'][16:22]):
    Restaurants.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# add pop-up text to each marker on the map
latitudes = list(MR['Latitude'][16:22])
longitudes = list(MR['Longitude'][16:22])
labels = list(MR['Name'][16:22])

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(MexicanR_map) 
    
# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(MR['Latitude'][22:28], MR['Longitude'][22:28]):
    Restaurants.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='red',
            fill=True,
            fill_color='red',
            fill_opacity=0.6
        )
    )

# add pop-up text to each marker on the map
latitudes = list(MR['Latitude'][22:28])
longitudes = list(MR['Longitude'][22:28])
labels = list(MR['Name'][22:28])


for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(MexicanR_map) 
    
    
    
    
# add incidents to map
MexicanR_map.add_child(Restaurants)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Finally, I´m going to try a MultipleLinear Regression with two Features.

# %%
import numpy as np
from sklearn import linear_model
reg = linear_model.LinearRegression()

# %%
x = np.asanyarray(MR[['Tip_Counts','likes']])
y = np.asanyarray(MR[['Rating']])
reg.fit (x, y)
# The coefficients
print ('Coefficients: ', reg.coef_)
# Out:
# Coefficients:  [[ 0.00350762 -0.00042921]]

# %% [markdown]
# Here is the metric of the Model.

# %%
y_hat= reg.predict(MR[['Tip_Counts','likes']])
x = np.asanyarray(MR[['Tip_Counts','likes']])
y = np.asanyarray(MR[['Rating']])
print("Residual sum of squares: %.2f"
      % np.mean((y_hat - y) ** 2))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % reg.score(x, y))
# Out:
# Residual sum of squares: 0.29
# Variance score: 0.24

# %% [markdown]
# ### That´s all. Thank you!
